# %% [markdown]
# ## Miscellaneous
# This notebook consists of misc. work that is not fitted anywhere else at the moment. A sort of on-the-go notebook.

# %% [markdown]
# First up is a sun burst chart of the composition of TCIDs on TCDB, down to family-level.

# %%
print("Hello World!")
